# %%
from Bio.PDB import PDBParser
import numpy as np
import nglview
import os
import pandas as pd
from scipy.spatial.distance import cdist

# %%
rf_pdb='./02SEP24/nrm_wts/_0.pdb'
CD20_D='./6vja_relaxed_aligned_02SEP24.pdb'

# %%
view = nglview.show_structure_file(rf_pdb)  
view.add_component(CD20_D,color='blue')
view
# Out:
# NGLWidget()

# %%
def dir_to_df(directory='./',weights=None):
    # List all .pdb files in the directory
    pdb_files = [f for f in os.listdir(directory) if f.endswith('.pdb')]

    # Gather file paths and modified names
    file_info = []
    for file in pdb_files:
        full_path = os.path.join(directory, file)  # Full path to the file
        # Remove underscores and strip '.pdb' extension
        file_name = os.path.basename(file).replace('_', '').replace('.pdb', '')
        file_info.append({'RFDiff Path': full_path, 'File Name': file_name})

    df = pd.DataFrame(file_info)
    
    if weights:
        df['RF wts']=weights
        
    return df

# %%
# Create a DataFrame
nrm_wts_df = dir_to_df('../RFdiffusion/02SEP24/nrm_wts/',weights='normal')
beta_wts_df = dir_to_df('../RFdiffusion/02SEP24/beta_wts/',weights='beta')

# %%
def clashes_pdb_compare(pdb1=str,pdb2=CD20_D,rfdiff_chain_id='A',threshold=2.0):
    
    def get_coordinates(pdb_file):
        parser = PDBParser(QUIET=True)
        structure = parser.get_structure('structure', pdb_file)

        atoms = [atom for atom in structure.get_atoms()]
        coords = np.array([atom.coord for atom in atoms])

        return coords
    
    def get_chain_coordinates(pdb_file, chain_id):
        parser = PDBParser(QUIET=True)
        structure = parser.get_structure('structure', pdb_file)
        chain = structure[0][chain_id]  # Assuming only one model in the PDB file
        atoms = [atom for atom in chain.get_atoms()]
        coords = np.array([atom.coord for atom in atoms])
        return coords

    # Load coordinates from both PDB files
    pdb1_coords = get_chain_coordinates(pdb1,chain_id=rfdiff_chain_id)
    pdb2_coords = get_coordinates(pdb2)

    # Calculate pairwise distances between all atoms in pdb1 and pdb2
    distances = cdist(pdb1_coords, pdb2_coords)

    # Find overlaps/clashes
    overlaps = np.where(distances < threshold)

    # List atom pairs that are clashing
    clashes = [(i, j, distances[i, j]) for i, j in zip(*overlaps)]

    # Print the results
    print(f"Number of clashes: {len(clashes)}")
    #for clash in clashes:
    #    print(f"Atom in pdb1 (index {clash[0]}) and atom in pdb2 (index {clash[1]}) are within {clash[2]:.2f} Å")
    return len(clashes)

# %%
def count_chain_contacts(pdb_file, chain1_id='A', chain2_id='B', threshold=5.0):
    
    def get_chain_coordinates(structure, chain_id):
        chain = structure[0][chain_id]  # Assuming only one model in the PDB file
        atoms = [atom for atom in chain.get_atoms()]
        coords = np.array([atom.coord for atom in atoms])
        return coords

    # Parse the PDB file and get the structure
    parser = PDBParser(QUIET=True)
    structure = parser.get_structure('structure', pdb_file)
    
    # Get coordinates of atoms in each chain
    chain1_coords = get_chain_coordinates(structure, chain1_id)
    chain2_coords = get_chain_coordinates(structure, chain2_id)
    
    # Calculate pairwise distances between all atoms in chain1 and chain2
    distances = cdist(chain1_coords, chain2_coords)
    
    # Find contacts (pairs of atoms within the distance threshold)
    contacts = np.where(distances < threshold)
    
    # List atom pairs that are in contact
    contacts_list = [(i, j, distances[i, j]) for i, j in zip(*contacts)]
    
    # Print the results
    print(f"Number of contacts: {len(contacts_list)}")
    #for contact in contacts_list:
    #    print(f"Atom in chain1 (index {contact[0]}) and atom in chain2 (index {contact[1]}) are within {contact[2]:.2f} Å")
    
    return len(contacts_list)

# %%
all_RFdiff=pd.concat([nrm_wts_df,beta_wts_df],ignore_index=True)

# %%
all_RFdiff['Num Clashes'] = all_RFdiff['RFDiff Path'].apply(clashes_pdb_compare)
# Out:
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 12
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 9
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 7
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 14
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 7
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 7
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 3
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 12
# Number of clashes: 11
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 10
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 9
# Number of clashes: 7
# Number of clashes: 4
# Number of clashes: 11
# Number of clashes: 13
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 16
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 11
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 8
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 7
# Number of clashes: 8
# Number of clashes: 15
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 7
# Number of clashes: 6
# Number of clashes: 15
# Number of clashes: 8
# Number of clashes: 7
# Number of clashes: 11
# Number of clashes: 6
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 9
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 10
# Number of clashes: 4
# Number of clashes: 12
# Number of clashes: 13
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 10
# Number of clashes: 2
# Number of clashes: 8
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 15
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 7
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 10
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 10
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 7
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 9
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 4
# Number of clashes: 11
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 6
# Number of clashes: 8
# Number of clashes: 12
# Number of clashes: 10
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 14
# Number of clashes: 6
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 14
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 11
# Number of clashes: 3
# Number of clashes: 6
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 7
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 6
# Number of clashes: 6
# Number of clashes: 9
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 15
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 12
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 12
# Number of clashes: 5
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 10
# Number of clashes: 14
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 9
# Number of clashes: 17
# Number of clashes: 7
# Number of clashes: 9
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 13
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 11
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 9
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 10
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 10
# Number of clashes: 9
# Number of clashes: 12
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 9
# Number of clashes: 2
# Number of clashes: 9
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 14
# Number of clashes: 24
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 9
# Number of clashes: 5
# Number of clashes: 5
# Number of clashes: 9
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 16
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 5
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 7
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 20
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 2
# Number of clashes: 13
# Number of clashes: 1
# Number of clashes: 11
# Number of clashes: 14
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 10
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 9
# Number of clashes: 3
# Number of clashes: 10
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 9
# Number of clashes: 5
# Number of clashes: 87
# Number of clashes: 13
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 9
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 20
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 7
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 4
# Number of clashes: 7
# Number of clashes: 5
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 13
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 4
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 7
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 7
# Number of clashes: 5
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 15
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 17
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 17
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 4
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 14
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 16
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 12
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 8
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 10
# Number of clashes: 6
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 9
# Number of clashes: 1
# Number of clashes: 12
# Number of clashes: 1
# Number of clashes: 9
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 14
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 9
# Number of clashes: 10
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 6
# Number of clashes: 13
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 10
# Number of clashes: 1
# Number of clashes: 11
# Number of clashes: 6
# Number of clashes: 15
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 11
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 8
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 13
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 6
# Number of clashes: 4
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 9
# Number of clashes: 11
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 18
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 6
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 13
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 10
# Number of clashes: 4
# Number of clashes: 8
# Number of clashes: 12
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 6
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 11
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 12
# Number of clashes: 6
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 9
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 11
# Number of clashes: 13
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 13
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 14
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 13
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 7
# Number of clashes: 9
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 7
# Number of clashes: 16
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 10
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 16
# Number of clashes: 3
# Number of clashes: 7
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 5
# Number of clashes: 15
# Number of clashes: 2
# Number of clashes: 12
# Number of clashes: 1
# Number of clashes: 10
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 7
# Number of clashes: 21
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 111
# Number of clashes: 1
# Number of clashes: 16
# Number of clashes: 5
# Number of clashes: 3
# Number of clashes: 5
# Number of clashes: 3
# Number of clashes: 8
# Number of clashes: 2
# Number of clashes: 139
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 8
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 10
# Number of clashes: 6
# Number of clashes: 5
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 10
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 8
# Number of clashes: 7
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 10
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 7
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 13
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 19
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 11
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 9
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 8
# Number of clashes: 7
# Number of clashes: 9
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 12
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 13
# Number of clashes: 9
# Number of clashes: 3
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 6
# Number of clashes: 6
# Number of clashes: 10
# Number of clashes: 4
# Number of clashes: 14
# Number of clashes: 5
# Number of clashes: 22
# Number of clashes: 4
# Number of clashes: 8
# Number of clashes: 11
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 14
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 10
# Number of clashes: 0
# Number of clashes: 14
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 14
# Number of clashes: 2
# Number of clashes: 14
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 18
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 18
# Number of clashes: 13
# Number of clashes: 117
# Number of clashes: 9
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 8
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 13
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 24
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 11
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 8
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 14
# Number of clashes: 10
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 3
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 17
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 5
# Number of clashes: 10
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 21
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 3
# Number of clashes: 5
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 18
# Number of clashes: 3
# Number of clashes: 25
# Number of clashes: 4
# Number of clashes: 9
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 6
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 11
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 7
# Number of clashes: 15
# Number of clashes: 7
# Number of clashes: 6
# Number of clashes: 9
# Number of clashes: 11
# Number of clashes: 18
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 17
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 14
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 3
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 11
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 3
# Number of clashes: 38
# Number of clashes: 8
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 9
# Number of clashes: 11
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 8
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 4
# Number of clashes: 10
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 14
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 5
# Number of clashes: 10
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 10
# Number of clashes: 3
# Number of clashes: 11
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 19
# Number of clashes: 7
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 13
# Number of clashes: 2
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 14
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 4
# Number of clashes: 12
# Number of clashes: 9
# Number of clashes: 11
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 8
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 12
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 9
# Number of clashes: 6
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 22
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 17
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 10
# Number of clashes: 8
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 6
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 9
# Number of clashes: 10
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 8
# Number of clashes: 16
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 31
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 13
# Number of clashes: 8
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 19
# Number of clashes: 21
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 12
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 6
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 16
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 9
# Number of clashes: 3
# Number of clashes: 11
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 58
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 12
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 6
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 10
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 13
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 8
# Number of clashes: 14
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 8
# Number of clashes: 1
# Number of clashes: 11
# Number of clashes: 14
# Number of clashes: 14
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 12
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 125
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 7
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 8
# Number of clashes: 9
# Number of clashes: 11
# Number of clashes: 9
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 10
# Number of clashes: 12
# Number of clashes: 9
# Number of clashes: 2
# Number of clashes: 8
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 7
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 24
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 5
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 14
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 9
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 8
# Number of clashes: 2
# Number of clashes: 9
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 8
# Number of clashes: 11
# Number of clashes: 10
# Number of clashes: 6
# Number of clashes: 0
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 3
# Number of clashes: 9
# Number of clashes: 4
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 9
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 9
# Number of clashes: 2
# Number of clashes: 11
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 8
# Number of clashes: 5
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 23
# Number of clashes: 8
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 5
# Number of clashes: 4
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 13
# Number of clashes: 6
# Number of clashes: 12
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 32
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 9
# Number of clashes: 14
# Number of clashes: 4
# Number of clashes: 9
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 10
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 22
# Number of clashes: 5
# Number of clashes: 1
# Number of clashes: 3
# Number of clashes: 5
# Number of clashes: 11
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 15
# Number of clashes: 1
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 5
# Number of clashes: 10
# Number of clashes: 1
# Number of clashes: 13
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 11
# Number of clashes: 17
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 4
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 10
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 20
# Number of clashes: 2
# Number of clashes: 7
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 2
# Number of clashes: 10
# Number of clashes: 11
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 6
# Number of clashes: 14
# Number of clashes: 2
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 5
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 5
# Number of clashes: 16
# Number of clashes: 4
# Number of clashes: 7
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 12
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 14
# Number of clashes: 11
# Number of clashes: 4
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 4
# Number of clashes: 190
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 4
# Number of clashes: 23
# Number of clashes: 8
# Number of clashes: 4
# Number of clashes: 3
# Number of clashes: 13
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 3
# Number of clashes: 10
# Number of clashes: 3
# Number of clashes: 1
# Number of clashes: 15
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 12
# Number of clashes: 9
# Number of clashes: 9
# Number of clashes: 2
# Number of clashes: 3
# Number of clashes: 2
# Number of clashes: 19
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 2
# Number of clashes: 14
# Number of clashes: 9
# Number of clashes: 11
# Number of clashes: 133
# Number of clashes: 0
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 3
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 9
# Number of clashes: 4
# Number of clashes: 3
# Number of clashes: 6
# Number of clashes: 1
# Number of clashes: 2
# Number of clashes: 0
# Number of clashes: 1
# Number of clashes: 25
# Number of clashes: 4
# Number of clashes: 5
# Number of clashes: 7
# Number of clashes: 6
# Number of clashes: 2
# Number of clashes: 17
# Number of clashes: 3
# Number of clashes: 0
# Number of clashes: 11
# Number of clashes: 0
# Number of clashes: 102
# Number of clashes: 0
# Number of clashes: 6
# Number of clashes: 13
# Number of clashes: 0
# Number of clashes: 7
# Number of clashes: 9
# Number of clashes: 0
# Number of clashes: 0

# %%
all_RFdiff['Num Clashes'].hist(bins=100)
# Out:
# <Axes: >

# %% [markdown]
# ### Scaffold with the most clashes

# %%
view = nglview.show_structure_file(
    all_RFdiff.sort_values('Num Clashes',
                           ascending=False).reset_index()['RFDiff Path'][0])  
view.add_component(CD20_D,color='blue')
view
# Out:
# NGLWidget()

# %% [markdown]
# ### Scaffold with the fewest clashes

# %%
view = nglview.show_structure_file(
    all_RFdiff.sort_values('Num Clashes',
                           ascending=True).reset_index()['RFDiff Path'][0])  
view.add_component(CD20_D,color='blue')
view
# Out:
# NGLWidget()

# %%
RFdiff_cleaned = all_RFdiff[all_RFdiff['Num Clashes']<5]

# %%
RFdiff_cleaned['Num RFDiff contacts'] = RFdiff_cleaned['RFDiff Path'].apply(count_chain_contacts)
# Out:
# Number of contacts: 5
# Number of contacts: 20
# Number of contacts: 44
# Number of contacts: 29
# Number of contacts: 33
# Number of contacts: 15
# Number of contacts: 21
# Number of contacts: 10
# Number of contacts: 18
# Number of contacts: 27
# Number of contacts: 13
# Number of contacts: 41
# Number of contacts: 8
# Number of contacts: 11
# Number of contacts: 10
# Number of contacts: 14
# Number of contacts: 46
# Number of contacts: 23
# Number of contacts: 24
# Number of contacts: 11
# Number of contacts: 34
# Number of contacts: 8
# Number of contacts: 21
# Number of contacts: 22
# Number of contacts: 7
# Number of contacts: 39
# Number of contacts: 10
# Number of contacts: 12
# Number of contacts: 17
# Number of contacts: 18
# Number of contacts: 18
# Number of contacts: 22
# Number of contacts: 44
# Number of contacts: 23
# Number of contacts: 29
# Number of contacts: 29
# Number of contacts: 11
# Number of contacts: 21
# Number of contacts: 4
# Number of contacts: 7
# Number of contacts: 37
# Number of contacts: 17
# Number of contacts: 35
# Number of contacts: 11
# Number of contacts: 8
# Number of contacts: 9
# Number of contacts: 16
# Number of contacts: 15
# Number of contacts: 14
# Number of contacts: 14
# Number of contacts: 26
# Number of contacts: 4
# Number of contacts: 14
# Number of contacts: 11
# Number of contacts: 25
# Number of contacts: 22
# Number of contacts: 10
# Number of contacts: 17
# Number of contacts: 1
# Number of contacts: 23
# Number of contacts: 6
# Number of contacts: 30
# Number of contacts: 10
# Number of contacts: 26
# Number of contacts: 29
# Number of contacts: 2
# Number of contacts: 26
# Number of contacts: 19
# Number of contacts: 5
# Number of contacts: 57
# Number of contacts: 59
# Number of contacts: 22
# Number of contacts: 5
# Number of contacts: 19
# Number of contacts: 8
# Number of contacts: 4
# Number of contacts: 24
# Number of contacts: 19
# Number of contacts: 34
# Number of contacts: 29
# Number of contacts: 14
# Number of contacts: 32
# Number of contacts: 14
# Number of contacts: 24
# Number of contacts: 20
# Number of contacts: 14
# Number of contacts: 2
# Number of contacts: 0
# Number of contacts: 22
# Number of contacts: 11
# Number of contacts: 18
# Number of contacts: 22
# Number of contacts: 0
# Number of contacts: 18
# Number of contacts: 31
# Number of contacts: 3
# Number of contacts: 9
# Number of contacts: 15
# Number of contacts: 18
# Number of contacts: 29
# Number of contacts: 13
# Number of contacts: 17
# Number of contacts: 22
# Number of contacts: 21
# Number of contacts: 28
# Number of contacts: 10
# Number of contacts: 7
# Number of contacts: 24
# Number of contacts: 0
# Number of contacts: 1
# Number of contacts: 17
# Number of contacts: 16
# Number of contacts: 10
# Number of contacts: 12
# Number of contacts: 1
# Number of contacts: 36
# Number of contacts: 16
# Number of contacts: 10
# Number of contacts: 25
# Number of contacts: 11
# Number of contacts: 16
# Number of contacts: 4
# Number of contacts: 12
# Number of contacts: 22
# Number of contacts: 15
# Number of contacts: 25
# Number of contacts: 10
# Number of contacts: 16
# Number of contacts: 33
# Number of contacts: 12
# Number of contacts: 9
# Number of contacts: 11
# Number of contacts: 23
# Number of contacts: 26
# Number of contacts: 34
# Number of contacts: 2
# Number of contacts: 17
# Number of contacts: 11
# Number of contacts: 12
# Number of contacts: 17
# Number of contacts: 76
# Number of contacts: 23
# Number of contacts: 38
# Number of contacts: 21
# Number of contacts: 1
# Number of contacts: 29
# Number of contacts: 1
# Number of contacts: 22
# Number of contacts: 18
# Number of contacts: 23
# Number of contacts: 16
# Number of contacts: 13
# Number of contacts: 29
# Number of contacts: 6
# Number of contacts: 5
# Number of contacts: 11
# Number of contacts: 30
# Number of contacts: 2
# Number of contacts: 23
# Number of contacts: 10
# Number of contacts: 32
# Number of contacts: 9
# Number of contacts: 27
# Number of contacts: 14
# Number of contacts: 36
# Number of contacts: 22
# Number of contacts: 2
# Number of contacts: 19
# Number of contacts: 49
# Number of contacts: 6
# Number of contacts: 5
# Number of contacts: 14
# Number of contacts: 7
# Number of contacts: 21
# Number of contacts: 19
# Number of contacts: 19
# Number of contacts: 42
# Number of contacts: 35
# Number of contacts: 18
# Number of contacts: 25
# Number of contacts: 27
# Number of contacts: 47
# Number of contacts: 22
# Number of contacts: 14
# Number of contacts: 49
# Number of contacts: 52
# Number of contacts: 4
# Number of contacts: 15
# Number of contacts: 32
# Number of contacts: 22
# Number of contacts: 28
# Number of contacts: 24
# Number of contacts: 13
# Number of contacts: 3
# Number of contacts: 18
# Number of contacts: 18
# Number of contacts: 22
# Number of contacts: 24
# Number of contacts: 47
# Number of contacts: 19
# Number of contacts: 7
# Number of contacts: 17
# Number of contacts: 19
# Number of contacts: 34
# Number of contacts: 15
# Number of contacts: 0
# Number of contacts: 14
# Number of contacts: 12
# Number of contacts: 18
# Number of contacts: 2
# Number of contacts: 18
# Number of contacts: 5
# Number of contacts: 15
# Number of contacts: 29
# Number of contacts: 1
# Number of contacts: 23
# Number of contacts: 19
# Number of contacts: 3
# Number of contacts: 12
# Number of contacts: 1
# Number of contacts: 37
# Number of contacts: 27
# Number of contacts: 68
# Number of contacts: 24
# Number of contacts: 9
# Number of contacts: 20
# Number of contacts: 7
# Number of contacts: 23
# Number of contacts: 33
# Number of contacts: 12
# Number of contacts: 14
# Number of contacts: 21
# Number of contacts: 20
# Number of contacts: 34
# Number of contacts: 19
# Number of contacts: 22
# Number of contacts: 22
# Number of contacts: 9
# Number of contacts: 22
# Number of contacts: 27
# Number of contacts: 31
# Number of contacts: 69
# Number of contacts: 7
# Number of contacts: 24
# Number of contacts: 13
# Number of contacts: 5
# Number of contacts: 9
# Number of contacts: 24
# Number of contacts: 62
# Number of contacts: 15
# Number of contacts: 14
# Number of contacts: 11
# Number of contacts: 73
# Number of contacts: 19
# Number of contacts: 22
# Number of contacts: 33
# Number of contacts: 20
# Number of contacts: 11
# Number of contacts: 33
# Number of contacts: 5
# Number of contacts: 9
# Number of contacts: 18
# Number of contacts: 8
# Number of contacts: 33
# Number of contacts: 17
# Number of contacts: 0
# Number of contacts: 5
# Number of contacts: 37
# Number of contacts: 7
# Number of contacts: 19
# Number of contacts: 30
# Number of contacts: 45
# Number of contacts: 19
# Number of contacts: 8
# Number of contacts: 18
# Number of contacts: 10
# Number of contacts: 8
# Number of contacts: 29
# Number of contacts: 19
# Number of contacts: 18
# Number of contacts: 32
# Number of contacts: 22
# Number of contacts: 37
# Number of contacts: 39
# Number of contacts: 23
# Number of contacts: 23
# Number of contacts: 3
# Number of contacts: 13
# Number of contacts: 32
# Number of contacts: 28
# Number of contacts: 13
# Number of contacts: 15
# Number of contacts: 23
# Number of contacts: 11
# Number of contacts: 11
# Number of contacts: 21
# Number of contacts: 23
# Number of contacts: 22
# Number of contacts: 6
# Number of contacts: 33
# Number of contacts: 46
# Number of contacts: 54
# Number of contacts: 4
# Number of contacts: 6
# Number of contacts: 16
# Number of contacts: 21
# Number of contacts: 10
# Number of contacts: 29
# Number of contacts: 6
# Number of contacts: 37
# Number of contacts: 20
# Number of contacts: 19
# Number of contacts: 18
# Number of contacts: 17
# Number of contacts: 36
# Number of contacts: 0
# Number of contacts: 25
# Number of contacts: 11
# Number of contacts: 29
# Number of contacts: 11
# Number of contacts: 20
# Number of contacts: 10
# Number of contacts: 2
# Number of contacts: 18
# Number of contacts: 16
# Number of contacts: 19
# Number of contacts: 31
# Number of contacts: 42
# Number of contacts: 18
# Number of contacts: 11
# Number of contacts: 17
# Number of contacts: 12
# Number of contacts: 21
# Number of contacts: 6
# Number of contacts: 50
# Number of contacts: 31
# Number of contacts: 19
# Number of contacts: 6
# Number of contacts: 33
# Number of contacts: 1
# Number of contacts: 21
# Number of contacts: 16
# Number of contacts: 8
# Number of contacts: 15
# Number of contacts: 19
# Number of contacts: 18
# Number of contacts: 14
# Number of contacts: 40
# Number of contacts: 16
# Number of contacts: 38
# Number of contacts: 7
# Number of contacts: 32
# Number of contacts: 31
# Number of contacts: 3
# Number of contacts: 34
# Number of contacts: 12
# Number of contacts: 4
# Number of contacts: 26
# Number of contacts: 27
# Number of contacts: 9
# Number of contacts: 20
# Number of contacts: 23
# Number of contacts: 33
# Number of contacts: 16
# Number of contacts: 2
# Number of contacts: 5
# Number of contacts: 46
# Number of contacts: 52
# Number of contacts: 42
# Number of contacts: 15
# Number of contacts: 13
# Number of contacts: 24
# Number of contacts: 14
# Number of contacts: 18
# Number of contacts: 18
# Number of contacts: 26
# Number of contacts: 0
# Number of contacts: 35
# Number of contacts: 6
# Number of contacts: 63
# Number of contacts: 28
# Number of contacts: 20
# Number of contacts: 33
# Number of contacts: 30
# Number of contacts: 26
# Number of contacts: 52
# Number of contacts: 21
# Number of contacts: 14
# Number of contacts: 7
# Number of contacts: 4
# Number of contacts: 36
# Number of contacts: 16
# Number of contacts: 32
# Number of contacts: 24
# Number of contacts: 25
# Number of contacts: 13
# Number of contacts: 8
# Number of contacts: 22
# Number of contacts: 6
# Number of contacts: 2
# Number of contacts: 30
# Number of contacts: 29
# Number of contacts: 12
# Number of contacts: 10
# Number of contacts: 24
# Number of contacts: 8
# Number of contacts: 13
# Number of contacts: 8
# Number of contacts: 20
# Number of contacts: 19
# Number of contacts: 37
# Number of contacts: 18
# Number of contacts: 21
# Number of contacts: 18
# Number of contacts: 56
# Number of contacts: 7
# Number of contacts: 21
# Number of contacts: 14
# Number of contacts: 42
# Number of contacts: 16
# Number of contacts: 20
# Number of contacts: 15
# Number of contacts: 20
# Number of contacts: 21
# Number of contacts: 25
# Number of contacts: 39
# Number of contacts: 20
# Number of contacts: 23
# Number of contacts: 30
# Number of contacts: 29
# Number of contacts: 15
# Number of contacts: 45
# Number of contacts: 16
# Number of contacts: 23
# Number of contacts: 23
# Number of contacts: 23
# Number of contacts: 12
# Number of contacts: 25
# Number of contacts: 21
# Number of contacts: 24
# Number of contacts: 20
# Number of contacts: 19
# Number of contacts: 33
# Number of contacts: 18
# Number of contacts: 18
# Number of contacts: 56
# Number of contacts: 40
# Number of contacts: 25
# Number of contacts: 31
# Number of contacts: 8
# Number of contacts: 58
# Number of contacts: 39
# Number of contacts: 5
# Number of contacts: 27
# Number of contacts: 23
# Number of contacts: 23
# Number of contacts: 70
# Number of contacts: 6
# Number of contacts: 29
# Number of contacts: 28
# Number of contacts: 1
# Number of contacts: 23
# Number of contacts: 0
# Number of contacts: 23
# Number of contacts: 4
# Number of contacts: 24
# Number of contacts: 15
# Number of contacts: 16
# Number of contacts: 16
# Number of contacts: 10
# Number of contacts: 24
# Number of contacts: 66
# Number of contacts: 55
# Number of contacts: 15
# Number of contacts: 8
# Number of contacts: 20
# Number of contacts: 16
# Number of contacts: 24
# Number of contacts: 13
# Number of contacts: 20
# Number of contacts: 13
# Number of contacts: 9
# Number of contacts: 14
# Number of contacts: 37
# Number of contacts: 19
# Number of contacts: 19
# Number of contacts: 23
# Number of contacts: 8
# Number of contacts: 10
# Number of contacts: 17
# Number of contacts: 6
# Number of contacts: 6
# Number of contacts: 25
# Number of contacts: 14
# Number of contacts: 11
# Number of contacts: 13
# Number of contacts: 33
# Number of contacts: 10
# Number of contacts: 6
# Number of contacts: 18
# Number of contacts: 11
# Number of contacts: 14
# Number of contacts: 35
# Number of contacts: 1
# Number of contacts: 10
# Number of contacts: 25
# Number of contacts: 18
# Number of contacts: 8
# Number of contacts: 16
# Number of contacts: 34
# Number of contacts: 4
# Number of contacts: 13
# Number of contacts: 1
# Number of contacts: 61
# Number of contacts: 20
# Number of contacts: 13
# Number of contacts: 23
# Number of contacts: 15
# Number of contacts: 12
# Number of contacts: 17
# Number of contacts: 23
# Number of contacts: 42
# Number of contacts: 19
# Number of contacts: 18
# Number of contacts: 16
# Number of contacts: 3
# Number of contacts: 4
# Number of contacts: 8
# Number of contacts: 13
# Number of contacts: 28
# Number of contacts: 21
# Number of contacts: 6
# Number of contacts: 3
# Number of contacts: 29
# Number of contacts: 10
# Number of contacts: 16
# Number of contacts: 11
# Number of contacts: 40
# Number of contacts: 7
# Number of contacts: 35
# Number of contacts: 22
# Number of contacts: 9
# Number of contacts: 24
# Number of contacts: 4
# Number of contacts: 39
# Number of contacts: 20
# Number of contacts: 16
# Number of contacts: 21
# Number of contacts: 15
# Number of contacts: 22
# Number of contacts: 34
# Number of contacts: 8
# Number of contacts: 56
# Number of contacts: 32
# Number of contacts: 5
# Number of contacts: 47
# Number of contacts: 4
# Number of contacts: 35
# Number of contacts: 13
# Number of contacts: 36
# Number of contacts: 13
# Number of contacts: 22
# Number of contacts: 6
# Number of contacts: 19
# Number of contacts: 20
# Number of contacts: 21
# Number of contacts: 14
# Number of contacts: 22
# Number of contacts: 19
# Number of contacts: 19
# Number of contacts: 5
# Number of contacts: 17
# Number of contacts: 28
# Number of contacts: 19
# Number of contacts: 18
# Number of contacts: 27
# Number of contacts: 63
# Number of contacts: 14
# Number of contacts: 20
# Number of contacts: 3
# Number of contacts: 15
# Number of contacts: 23
# Number of contacts: 14
# Number of contacts: 19
# Number of contacts: 21
# Number of contacts: 22
# Number of contacts: 5
# Number of contacts: 23
# Number of contacts: 27
# Number of contacts: 5
# Number of contacts: 14
# Number of contacts: 25
# Number of contacts: 14
# Number of contacts: 12
# Number of contacts: 15
# Number of contacts: 0
# Number of contacts: 31
# Number of contacts: 10
# Number of contacts: 36
# Number of contacts: 22
# Number of contacts: 59
# Number of contacts: 36
# Number of contacts: 28
# Number of contacts: 32
# Number of contacts: 45
# Number of contacts: 17
# Number of contacts: 26
# Number of contacts: 16
# Number of contacts: 10
# Number of contacts: 10
# Number of contacts: 28
# Number of contacts: 17
# Number of contacts: 11
# Number of contacts: 15
# Number of contacts: 23
# Number of contacts: 3
# Number of contacts: 17
# Number of contacts: 19
# Number of contacts: 26
# Number of contacts: 11
# Number of contacts: 7
# Number of contacts: 12
# Number of contacts: 2
# Number of contacts: 29
# Number of contacts: 2
# Number of contacts: 46
# Number of contacts: 18
# Number of contacts: 11
# Number of contacts: 22
# Number of contacts: 35
# Number of contacts: 7
# Number of contacts: 41
# Number of contacts: 19
# Number of contacts: 4
# Number of contacts: 25
# Number of contacts: 21
# Number of contacts: 9
# Number of contacts: 15
# Number of contacts: 3
# Number of contacts: 19
# Number of contacts: 29
# Number of contacts: 27
# Number of contacts: 7
# Number of contacts: 8
# Number of contacts: 6
# Number of contacts: 13
# Number of contacts: 8
# Number of contacts: 13
# Number of contacts: 19
# Number of contacts: 11
# Number of contacts: 26
# Number of contacts: 30
# Number of contacts: 6
# Number of contacts: 27
# Number of contacts: 8
# Number of contacts: 21
# Number of contacts: 25
# Number of contacts: 9
# Number of contacts: 37
# Number of contacts: 5
# Number of contacts: 23
# Number of contacts: 47
# Number of contacts: 23
# Number of contacts: 14
# Number of contacts: 15
# Number of contacts: 10
# Number of contacts: 20
# Number of contacts: 36
# Number of contacts: 5
# Number of contacts: 8
# Number of contacts: 22
# Number of contacts: 25
# Number of contacts: 4
# Number of contacts: 37
# Number of contacts: 18
# Number of contacts: 20
# Number of contacts: 21
# Number of contacts: 39
# Number of contacts: 16
# Number of contacts: 21
# Number of contacts: 24
# Number of contacts: 2
# Number of contacts: 19
# Number of contacts: 37
# Number of contacts: 7
# Number of contacts: 16
# Number of contacts: 0
# Number of contacts: 24
# Number of contacts: 27
# Number of contacts: 23
# Number of contacts: 13
# Number of contacts: 6
# Number of contacts: 3
# Number of contacts: 29
# Number of contacts: 18
# Number of contacts: 39
# Number of contacts: 9
# Number of contacts: 54
# Number of contacts: 18
# Number of contacts: 42
# Number of contacts: 17
# Number of contacts: 36
# Number of contacts: 34
# Number of contacts: 8
# Number of contacts: 6
# Number of contacts: 28
# Number of contacts: 43
# Number of contacts: 36
# Number of contacts: 23
# Number of contacts: 35
# Number of contacts: 41
# Number of contacts: 7
# Number of contacts: 15
# Number of contacts: 7
# Number of contacts: 70
# Number of contacts: 19
# Number of contacts: 20
# Number of contacts: 15
# Number of contacts: 15
# Number of contacts: 26
# Number of contacts: 0
# Number of contacts: 43
# Number of contacts: 30
# Number of contacts: 13
# Number of contacts: 25
# Number of contacts: 33
# Number of contacts: 28
# Number of contacts: 14
# Number of contacts: 43
# Number of contacts: 45
# Number of contacts: 23
# Number of contacts: 14
# Number of contacts: 31
# Number of contacts: 53
# Number of contacts: 17
# Number of contacts: 28
# Number of contacts: 10
# Number of contacts: 25
# Number of contacts: 17
# Number of contacts: 21
# Number of contacts: 19
# Number of contacts: 30
# Number of contacts: 0
# Number of contacts: 60
# Number of contacts: 8
# Number of contacts: 19
# Number of contacts: 28
# Number of contacts: 39
# Number of contacts: 34
# Number of contacts: 18
# Number of contacts: 38
# Number of contacts: 7
# Number of contacts: 10
# Number of contacts: 2
# Number of contacts: 31
# Number of contacts: 44
# Number of contacts: 8
# Number of contacts: 31
# Number of contacts: 39
# Number of contacts: 37
# Number of contacts: 19
# Number of contacts: 29
# Number of contacts: 36
# Number of contacts: 29
# Number of contacts: 27
# Number of contacts: 17
# Number of contacts: 10
# Number of contacts: 30
# Number of contacts: 41
# Number of contacts: 37
# Number of contacts: 33
# Number of contacts: 16
# Number of contacts: 12
# Number of contacts: 17
# Number of contacts: 18
# Number of contacts: 34
# Number of contacts: 50
# Number of contacts: 51
# Number of contacts: 11
# Number of contacts: 43
# Number of contacts: 49
# Number of contacts: 23
# Number of contacts: 36
# Number of contacts: 11
# Number of contacts: 25
# Number of contacts: 5
# Number of contacts: 13
# Number of contacts: 15
# Number of contacts: 17
# Number of contacts: 19
# Number of contacts: 16
# Number of contacts: 53
# Number of contacts: 34
# Number of contacts: 7
# Number of contacts: 21
# Number of contacts: 25
# Number of contacts: 6
# Number of contacts: 24
# Number of contacts: 50
# Number of contacts: 34
# Number of contacts: 12
# Number of contacts: 13
# Number of contacts: 25
# Number of contacts: 52
# Number of contacts: 24
# Number of contacts: 2
# Number of contacts: 2
# Number of contacts: 8
# Number of contacts: 16
# Number of contacts: 28
# Number of contacts: 22
# Number of contacts: 12
# Number of contacts: 23
# Number of contacts: 12
# Number of contacts: 13
# Number of contacts: 5
# Number of contacts: 68
# Number of contacts: 18
# Number of contacts: 8
# Number of contacts: 13
# Number of contacts: 26
# Number of contacts: 16
# Number of contacts: 38
# Number of contacts: 11
# Number of contacts: 14
# Number of contacts: 9
# Number of contacts: 8
# Number of contacts: 16
# Number of contacts: 2
# Number of contacts: 21
# Number of contacts: 24
# Number of contacts: 13
# Number of contacts: 20
# Number of contacts: 5
# Number of contacts: 16
# Number of contacts: 32
# Number of contacts: 21
# Number of contacts: 10
# Number of contacts: 22
# Number of contacts: 25
# Number of contacts: 14
# Number of contacts: 21
# Number of contacts: 24
# Number of contacts: 42
# Number of contacts: 10
# Number of contacts: 30
# Number of contacts: 33
# Number of contacts: 3
# Number of contacts: 15
# Number of contacts: 33
# Number of contacts: 22
# Number of contacts: 21
# Number of contacts: 9
# Number of contacts: 14
# Number of contacts: 8
# Number of contacts: 23
# Number of contacts: 8
# Number of contacts: 2
# Number of contacts: 55
# Number of contacts: 82
# Number of contacts: 76
# Number of contacts: 48
# Number of contacts: 23
# Number of contacts: 23
# Number of contacts: 5
# Number of contacts: 33
# Number of contacts: 13
# Number of contacts: 17
# Number of contacts: 15
# Number of contacts: 10
# Number of contacts: 23
# Number of contacts: 25
# Number of contacts: 29
# Number of contacts: 48
# Number of contacts: 19
# Number of contacts: 56
# Number of contacts: 14
# Number of contacts: 22
# Number of contacts: 7
# Number of contacts: 13
# Number of contacts: 19
# Number of contacts: 6
# Number of contacts: 35
# Number of contacts: 20
# Number of contacts: 28
# Number of contacts: 15
# Number of contacts: 7
# Number of contacts: 15
# Number of contacts: 24
# Number of contacts: 27
# Number of contacts: 11
# Number of contacts: 62
# Number of contacts: 26
# Number of contacts: 26
# Number of contacts: 11
# Number of contacts: 28
# Number of contacts: 23
# Number of contacts: 11
# Number of contacts: 10
# Number of contacts: 21
# Number of contacts: 11
# Number of contacts: 7
# Number of contacts: 39
# Number of contacts: 4
# Number of contacts: 15
# Number of contacts: 24
# Number of contacts: 37
# Number of contacts: 45
# Number of contacts: 50
# Number of contacts: 36
# Number of contacts: 11
# Number of contacts: 18
# Number of contacts: 16
# Number of contacts: 49
# Number of contacts: 18
# Number of contacts: 10
# Number of contacts: 20
# Number of contacts: 8
# Number of contacts: 32
# Number of contacts: 20
# Number of contacts: 55
# Number of contacts: 14
# Number of contacts: 27
# Number of contacts: 17
# Number of contacts: 8
# Number of contacts: 10
# Number of contacts: 12
# Number of contacts: 24
# Number of contacts: 31
# Number of contacts: 0
# Number of contacts: 31
# Number of contacts: 42
# Number of contacts: 9
# Number of contacts: 16
# Number of contacts: 16
# Number of contacts: 15
# Number of contacts: 23
# Number of contacts: 30
# Number of contacts: 62
# Number of contacts: 25
# Number of contacts: 12
# Number of contacts: 14
# Number of contacts: 5
# Number of contacts: 37
# Number of contacts: 19
# Number of contacts: 18
# Number of contacts: 12
# Number of contacts: 44
# Number of contacts: 9
# Number of contacts: 21
# Number of contacts: 16
# Number of contacts: 43
# Number of contacts: 37
# Number of contacts: 19
# Number of contacts: 7
# Number of contacts: 16
# Number of contacts: 36
# Number of contacts: 20
# Number of contacts: 14
# Number of contacts: 16
# Number of contacts: 19
# Number of contacts: 2
# Number of contacts: 22
# Number of contacts: 23
# Number of contacts: 3
# Number of contacts: 14
# Number of contacts: 22
# Number of contacts: 15
# Number of contacts: 14
# Number of contacts: 27
# Number of contacts: 20
# Number of contacts: 16
# Number of contacts: 2
# Number of contacts: 1
# Number of contacts: 29
# Number of contacts: 37
# Number of contacts: 34
# Number of contacts: 8
# Number of contacts: 24
# Number of contacts: 57
# Number of contacts: 11
# Number of contacts: 37
# Number of contacts: 15
# Number of contacts: 6
# Number of contacts: 3
# Number of contacts: 5
# Number of contacts: 21
# Number of contacts: 56
# Number of contacts: 22
# Number of contacts: 22
# Number of contacts: 6
# Number of contacts: 21
# Number of contacts: 17
# Number of contacts: 4
# Number of contacts: 25
# Number of contacts: 20
# Number of contacts: 3
# Number of contacts: 11
# Number of contacts: 8
# Number of contacts: 19
# Number of contacts: 24
# Number of contacts: 14
# Number of contacts: 28
# Number of contacts: 44
# Number of contacts: 13
# Number of contacts: 12
# Number of contacts: 106
# Number of contacts: 38
# Number of contacts: 7
# Number of contacts: 45
# Number of contacts: 17
# Number of contacts: 9
# Number of contacts: 24
# Number of contacts: 9
# Number of contacts: 12
# Number of contacts: 19
# Number of contacts: 4
# Number of contacts: 34
# Number of contacts: 27
# Number of contacts: 21
# Number of contacts: 0
# Number of contacts: 40
# Number of contacts: 41
# Number of contacts: 26
# Number of contacts: 9
# Number of contacts: 24
# Number of contacts: 45
# Number of contacts: 8
# Number of contacts: 29
# Number of contacts: 9
# Number of contacts: 26
# Number of contacts: 5
# Number of contacts: 16
# Number of contacts: 15
# Number of contacts: 32
# Number of contacts: 9
# Number of contacts: 15
# Number of contacts: 4
# Number of contacts: 11
# Number of contacts: 20
# Number of contacts: 26
# Number of contacts: 1
# Number of contacts: 7
# Number of contacts: 22
# Number of contacts: 29
# Number of contacts: 40
# Number of contacts: 3
# Number of contacts: 33
# Number of contacts: 12
# Number of contacts: 19
# Number of contacts: 27
# Number of contacts: 38
# Number of contacts: 61
# Number of contacts: 27
# Number of contacts: 48
# Number of contacts: 18
# Number of contacts: 9
# Number of contacts: 22
# Number of contacts: 53
# Number of contacts: 34
# Number of contacts: 11
# Number of contacts: 34
# Number of contacts: 14
# Number of contacts: 17
# Number of contacts: 22
# Number of contacts: 24
# Number of contacts: 16
# Number of contacts: 22
# Number of contacts: 17
# Number of contacts: 21
# Number of contacts: 22
# Number of contacts: 21
# Number of contacts: 23
# Number of contacts: 25
# Number of contacts: 16
# Number of contacts: 27
# Number of contacts: 10
# Number of contacts: 22
# Number of contacts: 33
# Number of contacts: 28
# Number of contacts: 15
# Number of contacts: 19
# Number of contacts: 13
# Number of contacts: 30
# Number of contacts: 57
# Number of contacts: 24
# Number of contacts: 9
# Number of contacts: 59
# Number of contacts: 16
# Number of contacts: 18
# Number of contacts: 9
# Number of contacts: 17
# Number of contacts: 31
# Number of contacts: 48
# Number of contacts: 3
# Number of contacts: 6
# Number of contacts: 44
# Number of contacts: 2
# Number of contacts: 15
# Number of contacts: 5
# Number of contacts: 26
# Number of contacts: 12
# Number of contacts: 71
# Number of contacts: 35
# Number of contacts: 7
# Number of contacts: 0
# Number of contacts: 25
# Number of contacts: 46
# Number of contacts: 8
# Number of contacts: 14
# Number of contacts: 18
# Number of contacts: 26
# Number of contacts: 16
# Number of contacts: 35
# Number of contacts: 38
# Number of contacts: 16
# Number of contacts: 16
# Number of contacts: 19
# Number of contacts: 39
# Number of contacts: 14
# Number of contacts: 91
# Number of contacts: 7
# Number of contacts: 2
# Number of contacts: 14
# Number of contacts: 10
# Number of contacts: 10
# Number of contacts: 20
# Number of contacts: 19
# Number of contacts: 11
# Number of contacts: 19
# Number of contacts: 10
# Number of contacts: 9
# Number of contacts: 26
# Number of contacts: 15
# Number of contacts: 70
# Number of contacts: 5
# Number of contacts: 15
# Number of contacts: 35
# Number of contacts: 36
# Number of contacts: 11
# Number of contacts: 53
# Number of contacts: 10
# Number of contacts: 29
# Number of contacts: 48
# Number of contacts: 23
# Number of contacts: 60
# Number of contacts: 38
# Number of contacts: 25
# Number of contacts: 7
# Number of contacts: 38
# Number of contacts: 9
# Number of contacts: 54
# Number of contacts: 8
# Number of contacts: 33
# Number of contacts: 16
# Number of contacts: 55
# Number of contacts: 1
# Number of contacts: 30
# Number of contacts: 5
# Number of contacts: 11
# Number of contacts: 27
# Number of contacts: 15
# Number of contacts: 8
# Number of contacts: 42
# Number of contacts: 3
# Number of contacts: 25
# Number of contacts: 39
# Number of contacts: 14
# Number of contacts: 56
# Number of contacts: 23
# Number of contacts: 11
# Number of contacts: 37
# Number of contacts: 28
# Number of contacts: 9
# Number of contacts: 21
# Number of contacts: 11
# Number of contacts: 1
# Number of contacts: 6
# Number of contacts: 14
# Number of contacts: 32
# Number of contacts: 34
# Number of contacts: 13
# Number of contacts: 16
# Number of contacts: 12
# Number of contacts: 42
# Number of contacts: 28
# Number of contacts: 15
# Number of contacts: 41
# Number of contacts: 13
# Number of contacts: 21
# Number of contacts: 57
# Number of contacts: 8
# Number of contacts: 10
# Number of contacts: 28
# Number of contacts: 12
# Number of contacts: 5
# Number of contacts: 17
# Number of contacts: 10
# Number of contacts: 11
# Number of contacts: 19
# Number of contacts: 15
# Number of contacts: 18
# Number of contacts: 22
# Number of contacts: 21
# Number of contacts: 49
# Number of contacts: 7
# Number of contacts: 17
# Number of contacts: 7
# Number of contacts: 14
# Number of contacts: 8
# Number of contacts: 18
# Number of contacts: 5
# Number of contacts: 29
# Number of contacts: 7
# Number of contacts: 23
# Number of contacts: 33
# Number of contacts: 30
# Number of contacts: 40
# Number of contacts: 27
# Number of contacts: 34
# Number of contacts: 43
# Number of contacts: 45
# Number of contacts: 11
# Number of contacts: 7
# Number of contacts: 7
# Number of contacts: 24
# Number of contacts: 2
# Number of contacts: 28
# Number of contacts: 27
# Number of contacts: 35
# Number of contacts: 24
# Number of contacts: 33
# Number of contacts: 0
# Number of contacts: 29
# Number of contacts: 33
# Number of contacts: 25
# Number of contacts: 18
# Number of contacts: 19
# Number of contacts: 42
# Number of contacts: 16
# Number of contacts: 53
# Number of contacts: 21
# Number of contacts: 35
# Number of contacts: 9
# Number of contacts: 15
# Number of contacts: 3
# Number of contacts: 20
# Number of contacts: 17
# Number of contacts: 11
# Number of contacts: 30
# Number of contacts: 24
# Number of contacts: 47
# Number of contacts: 1
# Number of contacts: 45
# Number of contacts: 15
# Number of contacts: 15
# Number of contacts: 3
# Number of contacts: 2
# Number of contacts: 4
# Number of contacts: 17
# Number of contacts: 42
# Number of contacts: 9
# Number of contacts: 30
# Number of contacts: 38
# Number of contacts: 29
# Number of contacts: 82
# Number of contacts: 17
# Number of contacts: 3
# Number of contacts: 35
# Number of contacts: 20
# Number of contacts: 22
# Number of contacts: 10
# Number of contacts: 40
# Number of contacts: 23
# Number of contacts: 18
# Number of contacts: 28
# Number of contacts: 14
# Number of contacts: 26
# Number of contacts: 3
# Number of contacts: 22
# Number of contacts: 118
# Number of contacts: 17
# Number of contacts: 19
# Number of contacts: 29
# Number of contacts: 35
# Number of contacts: 40
# Number of contacts: 18
# Number of contacts: 11
# Number of contacts: 33
# Number of contacts: 28
# Number of contacts: 19
# Number of contacts: 12
# Number of contacts: 7
# Number of contacts: 24
# Number of contacts: 29
# Number of contacts: 24
# Number of contacts: 49
# Number of contacts: 16
# Number of contacts: 17
# Number of contacts: 28
# Number of contacts: 28
# Number of contacts: 36
# Number of contacts: 24
# Number of contacts: 45
# Number of contacts: 20
# Number of contacts: 24
# Number of contacts: 28
# Number of contacts: 28
# Number of contacts: 23
# Number of contacts: 12
# Number of contacts: 9
# Number of contacts: 15
# Number of contacts: 8
# Number of contacts: 21
# Number of contacts: 19
# Number of contacts: 38
# Number of contacts: 35
# Number of contacts: 24
# Number of contacts: 28
# Number of contacts: 23
# Number of contacts: 9
# Number of contacts: 17
# Number of contacts: 16
# Number of contacts: 68
# Number of contacts: 16
# Number of contacts: 12
# Number of contacts: 40
# Number of contacts: 4
# Number of contacts: 19
# Number of contacts: 18
# Number of contacts: 54
# /var/folders/k0/7lzlp98x6c188pkk0rzbn2d40000gn/T/ipykernel_9504/3089438409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RFdiff_cleaned['Num RFDiff contacts'] = RFdiff_cleaned['RFDiff Path'].apply(count_chain_contacts)

# %%
RFdiff_cleaned['Num RFDiff contacts'].hist(bins=100)
# Out:
# <Axes: >

# %%
RFdiff_cleaned = RFdiff_cleaned[
    RFdiff_cleaned['Num RFDiff contacts']>(np.mean(RFdiff_cleaned['Num RFDiff contacts'])+ \
     np.std(RFdiff_cleaned['Num RFDiff contacts']))]

# %%
RFdiff_cleaned=RFdiff_cleaned.sort_values('Num RFDiff contacts',ascending=False)
RFdiff_cleaned = RFdiff_cleaned.reset_index(drop=True)

# %%
len(RFdiff_cleaned)

# %% [markdown]
# ### Structure with the most contacts

# %%
view = nglview.show_structure_file(RFdiff_cleaned['RFDiff Path'][0])  
view.add_component(CD20_D,color='blue')
view
# Out:
# NGLWidget()

# %%
RFdiff_cleaned['Name']=RFdiff_cleaned['RF wts']+'_'+RFdiff_cleaned['File Name']

# %%
RFdiff_cleaned['RF wts'].value_counts()
# Out:
# RF wts
# beta      115
# normal     74
# Name: count, dtype: int64

# %%
import shutil

# Define the new directory where you want to copy the files
new_directory = '../PMPNN/02SEP24/'


# Ensure the new directory exists, create it if it doesn't
os.makedirs(new_directory, exist_ok=True)

# Loop over each row in the RFdiff_cleaned DataFrame
for index, row in RFdiff_cleaned.iterrows():
    full_path = row['RFDiff Path']  # Original full path of the pdb file
    new_file_name = row['Name'] + '.pdb'  # New file name based on the 'name' column
    
    # Define the destination path
    destination = os.path.join(new_directory, new_file_name)
    
    # Copy the file to the new directory with the new name
    shutil.copy(full_path, destination)

print("All files have been copied and renamed successfully.")
# Out:
# All files have been copied and renamed successfully.
