# %%
import os

# %%
import nglview

# %%
pdb_of_interest = "./gp59_gp67_merged_2_no_ramaout.pdb"

# %%
view = nglview.show_structure_file(pdb_of_interest)  # load "3pqr" from RCSB PDB and display viewer widget
view
# Out:
# NGLWidget()

# %%
import FM_relax_utils

# %%
outfile = '/Users/phr361/Documents/Coding/TaylorGroup/Shweta/RosettaRelax/out/'

# %%
os.mkdir(outfile)

# %%
FM_relax_utils.run_relax(pdb=pdb_of_interest,outfile=outfile)
# Out:
# Processing file: ./gp59_gp67_merged_2_no_ramaout.pdb
# /Users/phr361/rosetta_bin_mac_2021.16.61629_bundle/main/source/bin/relax.static.macosclangrelease -s ./gp59_gp67_merged_2_no_ramaout.pdb -out:path:all /Users/phr361/Documents/Coding/TaylorGroup/Shweta/RosettaRelax/out/ @/Users/phr361/Documents/Coding/RosettaFiles/rosetta_relax/02_scripts/relax.flags
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: rosetta.binary.mac.release-280 r280 2021.16+release.8ee4f02ac57 8ee4f02ac5768a8a339ffada74cb0ff5f778b3e6 https://www.rosettacommons.org 2021-04-20T11:45:16.822269
# core.init: command: /Users/phr361/rosetta_bin_mac_2021.16.61629_bundle/main/source/bin/relax.static.macosclangrelease -s ./gp59_gp67_merged_2_no_ramaout.pdb -out:path:all /Users/phr361/Documents/Coding/TaylorGroup/Shweta/RosettaRelax/out/ @/Users/phr361/Documents/Coding/RosettaFiles/rosetta_relax/02_scripts/relax.flags
# ...

# %%
relaxed_pdb = ""
view = nglview.show_structure_file(relaxed_pdb)  # load "3pqr" from RCSB PDB and display viewer widget
view

# %%
FM_relax_utils.run_relax(pdb=pdb_of_interest,flags='/Users/phr361/Documents/Coding/RosettaFiles/rosetta_relax/02_scripts/intense_relax_100.flags')
